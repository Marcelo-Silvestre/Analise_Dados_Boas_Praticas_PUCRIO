# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcelo-Silvestre/Analise_Dados_Boas_Praticas_PUCRIO/blob/main/Notebooks/jogos_estudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url_base = pd.read_excel("https://raw.githubusercontent.com/Marcelo-Silvestre/Estudo_jogos/main/bases/Lotof%C3%A1cil.xlsx")

# %%
df_jogos = pd.DataFrame(url_base)
df_jogos.head()
# Out:
#    Concurso Data Sorteio  Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  \
# 0         1   29/09/2003      2      3      5      6      9     10     11
# 1         2   06/10/2003      1      4      5      6      7      9     11
# 2         3   13/10/2003      1      4      6      7      8      9     10
# 3         4   20/10/2003      1      2      4      5      8     10     12
# 4         5   27/10/2003      1      2      4      8      9     11     12
#
#    Bola8  ...  Rateio 13 acertos  Ganhadores 12 acertos  Rateio 12 acertos  \
# 0     13  ...            R$10,00                  48807             R$4,00
# 1     12  ...            R$10,00                  81252             R$4,00
# 2     11  ...            R$10,00                  96244             R$4,00
# 3     13  ...            R$10,00                 123912             R$4,00
# 4     13  ...            R$10,00                 195636             R$4,00
#
#    Ganhadores 11 acertos  Rateio 11 acertos  Acumulado 15 acertos  \
# ...

# %%
df_sorteados = df_jogos.iloc[:,2:17]
df_sorteados
# Out:
#       Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  Bola8  Bola9  Bola10  \
# 0         2      3      5      6      9     10     11     13     14      16
# 1         1      4      5      6      7      9     11     12     13      15
# 2         1      4      6      7      8      9     10     11     12      14
# 3         1      2      4      5      8     10     12     13     16      17
# 4         1      2      4      8      9     11     12     13     15      16
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 3653      1      2      3      4      6      7     11     15     17      19
# 3654      1      2      4      5      6     10     11     12     17      18
# 3655      3      4      6      7      8     11     12     14     15      18
# 3656      1      2      4      7      8     10     12     13     17      18
# 3657      2      3      4      5      9     10     11     12     13      16
#
#       Bola11  Bola12  Bola13  Bola14  Bola15
# ...

# %%
df_bola1 = df_sorteados['Bola1'].unique()
df_bola1
# Out:
# array([2, 1, 3, 5, 4, 6, 7, 9])

# %%
sorteio_bola1_1 = df_sorteados[df_sorteados['Bola1'] == 1]
sorteio_bola1_1
# Out:
#       Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  Bola8  Bola9  Bola10  \
# 1         1      4      5      6      7      9     11     12     13      15
# 2         1      4      6      7      8      9     10     11     12      14
# 3         1      2      4      5      8     10     12     13     16      17
# 4         1      2      4      8      9     11     12     13     15      16
# 5         1      2      4      5      6      7     10     12     15      16
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 3647      1      2      5      7      8      9     10     11     13      14
# 3651      1      3      6      7     11     12     13     15     16      18
# 3653      1      2      3      4      6      7     11     15     17      19
# 3654      1      2      4      5      6     10     11     12     17      18
# 3656      1      2      4      7      8     10     12     13     17      18
#
#       Bola11  Bola12  Bola13  Bola14  Bola15
# ...

# %%
print(len(sorteio_bola1_2))
# Out:
# 899

# %%
df_bola2 = df_sorteados['Bola2'].unique()
df_bola2
# Out:
# array([ 3,  4,  2,  5,  6,  7,  8,  9, 10])

# %%
print(len(df_bola2))
# Out:
# 9

# %%
sorteio_bola1_2 = df_sorteados[df_sorteados['Bola1'] == 2]
sorteio_bola1_2
# Out:
#       Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  Bola8  Bola9  Bola10  \
# 0         2      3      5      6      9     10     11     13     14      16
# 9         2      3      4      5      6      8      9     10     11      12
# 10        2      6      7      8      9     10     11     12     16      19
# 15        2      5      6      7      8     10     12     13     15      17
# 17        2      6      7      8     10     11     14     15     17      18
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 3646      2      4      5      8     10     12     15     16     17      19
# 3649      2      5      6      7      8     10     11     12     13      16
# 3650      2      3      5      8     10     12     13     14     16      17
# 3652      2      3      4      6      7      8     10     11     13      14
# 3657      2      3      4      5      9     10     11     12     13      16
#
#       Bola11  Bola12  Bola13  Bola14  Bola15
# ...

# %%
print(len(sorteio_bola1_2))
# Out:
# 899

# %%
df_bola3 = df_sorteados['Bola3'].unique()
df_bola3
# Out:
# array([ 5,  6,  4,  7,  3,  8,  9, 11, 10, 12])

# %%
print(len(df_bola3))
# Out:
# 10

# %%
df_bola4 = df_sorteados['Bola4'].unique()
df_bola4
# Out:
# array([ 6,  7,  5,  8,  9,  4, 10, 12, 11, 13])

# %%
print(len(df_bola4))
# Out:
# 10

# %%
df_bola5 = df_sorteados['Bola5'].unique()
df_bola5
# Out:
# array([ 9,  7,  8,  6, 10,  5, 11, 12, 13, 14])

# %%
print(len(df_bola5))
# Out:
# 10

# %%
df_bola6 = df_sorteados['Bola6'].unique()
df_bola6
# Out:
# array([10,  9, 11,  7, 12,  8,  6, 13, 15, 14, 16])

# %%
print(len(df_bola6))
# Out:
# 11

# %%
df_bola7 = df_sorteados['Bola7'].unique()
df_bola7
# Out:
# array([11, 10, 12, 14, 13,  9,  7,  8, 15, 16, 17])

# %%
print(len(df_bola7))
# Out:
# 11

# %%
df_bola8 = df_sorteados['Bola8'].unique()
df_bola8
# Out:
# array([13, 12, 11, 15, 10, 14, 16,  9, 17,  8, 18])

# %%
print(len(df_bola8))
# Out:
# 11

# %%
df_bola9 = df_sorteados['Bola9'].unique()
df_bola9
# Out:
# array([14, 13, 12, 16, 15, 11, 17, 18, 10, 19,  9])

# %%
print(len(df_bola9))
# Out:
# 11

# %%
df_bola10 = df_sorteados['Bola10'].unique()
df_bola10
# Out:
# array([16, 15, 14, 17, 18, 12, 19, 13, 20, 11, 10])

# %%
print(len(df_bola10))
# Out:
# 11

# %%
df_bola11 = df_sorteados['Bola11'].unique()
df_bola11
# Out:
# array([18, 16, 19, 17, 14, 20, 15, 13, 21, 12])

# %%
print(len(df_bola11))
# Out:
# 10

# %%
df_bola12 = df_sorteados['Bola12'].unique()
df_bola12
# Out:
# array([20, 19, 17, 21, 22, 16, 18, 14, 15, 13])

# %%
print(len(df_bola12))
# Out:
# 10

# %%
df_bola13 = df_sorteados['Bola13'].unique()
df_bola13
# Out:
# array([23, 20, 21, 22, 17, 19, 15, 18, 16])

# %%
print(len(df_bola13))
# Out:
# 9

# %%
df_bola14 = df_sorteados['Bola14'].unique()
df_bola14
# Out:
# array([24, 23, 22, 19, 20, 21, 18, 17])

# %%
print(len(df_bola14))
# Out:
# 8

# %%
df_bola15 = df_sorteados['Bola15'].unique()
df_bola15
# Out:
# array([25, 24, 23, 21, 20, 22, 19, 18])

# %%
print(len(df_bola15))
# Out:
# 8
